# %%
import tensorflow as tf
import numpy as np
import json
import os
from pathlib import Path
import cv2
from tqdm import tqdm

# %%
class BabyDatasetLoader:
    def __init__(self, base_path, batch_size=32, img_size=640):
        self.base_path = Path(base_path)
        self.batch_size = batch_size
        self.img_size = img_size
        
    def load_coco_annotations(self, split):
        json_path = self.base_path / split / '_annotations.coco.json'
        with open(json_path, 'r') as f:
            return json.load(f)
        
    def preprocess_image(self, image_path):
        # Read and resize image
        img = cv2.imread(str(image_path))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = cv2.resize(img, (self.img_size, self.img_size))
        return img.astype(np.float32) / 255.0
    
    def create_dataset(self, split):
        coco_data = self.load_coco_annotations(split)
        
        # Create image id to annotations mapping
        img_to_anns = {}
        for ann in coco_data['annotations']:
            img_id = ann['image_id']
            if img_id not in img_to_anns:
                img_to_anns[img_id] = []
            img_to_anns[img_id].append(ann)
        
        images = []
        labels = []
        
        # Process each image
        for img_info in tqdm(coco_data['images'], desc=f'Loading {split} dataset'):
            img_path = self.base_path / split / img_info['file_name']
            img = self.preprocess_image(img_path)
            
            # Create label tensor [x, y, w, h, confidence]
            label = np.zeros((5,), dtype=np.float32)
            
            # If image has annotations, use the first one (assuming one baby per image)
            if img_info['id'] in img_to_anns:
                ann = img_to_anns[img_info['id']][0]
                x, y, w, h = ann['bbox']
                
                # Normalize coordinates
                label[0] = x / img_info['width']
                label[1] = y / img_info['height']
                label[2] = w / img_info['width']
                label[3] = h / img_info['height']
                label[4] = 1.0  # confidence
            
            images.append(img)
            labels.append(label)
        
        # Convert to TensorFlow dataset
        dataset = tf.data.Dataset.from_tensor_slices((
            np.array(images, dtype=np.float32),
            np.array(labels, dtype=np.float32)
        ))
        
        return dataset.shuffle(1000).batch(self.batch_size).prefetch(tf.data.AUTOTUNE)

# %%
def create_model():
    # Use EfficientNetV2B0 as base - good balance of size and accuracy
    base_model = tf.keras.applications.EfficientNetV2B0(
        input_shape=(640, 640, 3),
        include_top=False,
        weights='imagenet'
    )
    
    # Freeze the base model
    base_model.trainable = False
    
    inputs = tf.keras.Input(shape=(640, 640, 3))
    x = base_model(inputs)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    # Output: [x, y, width, height, confidence]
    outputs = tf.keras.layers.Dense(5, activation='sigmoid')(x)
    
    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
def train_model(model, train_dataset, valid_dataset, epochs=50):
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
        loss=tf.keras.losses.MeanSquaredError(),
        metrics=[
            tf.keras.metrics.MeanAbsoluteError(name='mae'),
            tf.keras.metrics.MeanSquaredError(name='mse')
        ]
    )
    
    callbacks = [
        tf.keras.callbacks.ModelCheckpoint(
            'best.weights.h5',  # File name to save the weights
            save_weights_only=True,  # Save only the weights
            save_best_only=True,  # Save only the best weights (based on `monitor`)
            monitor='val_loss'   # Metric to monitor
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=10,
            restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5
        )
    ]

    history = model.fit(
        train_dataset,
        validation_data=valid_dataset,
        epochs=epochs,
        callbacks=callbacks
    )
    
    return history

# %%
def convert_to_tflite(model):
    # Convert to TFLite with optimizations
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    converter.target_spec.supported_types = [tf.float16]
    
    # Enable GPU acceleration
    converter.target_spec.supported_ops = [
        tf.lite.OpsSet.TFLITE_BUILTINS,
        tf.lite.OpsSet.SELECT_TF_OPS
    ]
    
    tflite_model = converter.convert()
    
    # Save model
    with open('baby_detector.tflite', 'wb') as f:
        f.write(tflite_model)
    
    # Print model size
    print(f"Model size: {len(tflite_model) / 1024 / 1024:.2f} MB")

# %%
def main():
    # Initialize dataset loader
    dataset_loader = BabyDatasetLoader(
        base_path='data/BabyMonitor.v1i.coco',
        batch_size=32,
        img_size=640
    )
    
    # Load datasets
    train_dataset = dataset_loader.create_dataset('train')
    valid_dataset = dataset_loader.create_dataset('valid')
    test_dataset = dataset_loader.create_dataset('test')
    
    # Create and train model
    model = create_model()
    history = train_model(model, train_dataset, valid_dataset)
    
    # Evaluate on test set
    test_results = model.evaluate(test_dataset)
    print("\nTest Results:")
    for metric, value in zip(model.metrics_names, test_results):
        print(f"{metric}: {value:.4f}")
    
    # Convert to TFLite
    convert_to_tflite(model)

if __name__ == "__main__":
    main()
# Out:
# Loading train dataset: 100%|██████████| 1686/1686 [00:08<00:00, 192.51it/s]
# Loading valid dataset: 100%|██████████| 46/46 [00:00<00:00, 153.24it/s]
# Loading test dataset: 100%|██████████| 45/45 [00:00<00:00, 171.75it/s]
# Epoch 1/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 44s 657ms/step - loss: 0.0385 - mae: 0.1451 - mse: 0.0385 - val_loss: 0.0192 - val_mae: 0.0995 - val_mse: 0.0192 - learning_rate: 0.0010
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 545ms/step - loss: 0.0315 - mae: 0.1252 - mse: 0.0315 - val_loss: 0.0203 - val_mae: 0.1054 - val_mse: 0.0203 - learning_rate: 0.0010
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 30s 557ms/step - loss: 0.0325 - mae: 0.1289 - mse: 0.0325 - val_loss: 0.0209 - val_mae: 0.1058 - val_mse: 0.0209 - learning_rate: 0.0010
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 542ms/step - loss: 0.0310 - mae: 0.1256 - mse: 0.0310 - val_loss: 0.0221 - val_mae: 0.1079 - val_mse: 0.0221 - learning_rate: 0.0010
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 540ms/step - loss: 0.0299 - mae: 0.1244 - mse: 0.0299 - val_loss: 0.0233 - val_mae: 0.1137 - val_mse: 0.0233 - learning_rate: 0.0010
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 536ms/step - loss: 0.0319 - mae: 0.1275 - mse: 0.0319 - val_loss: 0.0224 - val_mae: 0.1106 - val_mse: 0.0224 - learning_rate: 0.0010
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 543ms/step - loss: 0.0301 - mae: 0.1248 - mse: 0.0301 - val_loss: 0.0209 - val_mae: 0.1075 - val_mse: 0.0209 - learning_rate: 5.0000e-04
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 545ms/step - loss: 0.0299 - mae: 0.1251 - mse: 0.0299 - val_loss: 0.0208 - val_mae: 0.1069 - val_mse: 0.0208 - learning_rate: 5.0000e-04
# Epoch 9/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 554ms/step - loss: 0.0312 - mae: 0.1269 - mse: 0.0312 - val_loss: 0.0191 - val_mae: 0.1010 - val_mse: 0.0191 - learning_rate: 5.0000e-04
# Epoch 10/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 549ms/step - loss: 0.0301 - mae: 0.1243 - mse: 0.0301 - val_loss: 0.0202 - val_mae: 0.1059 - val_mse: 0.0202 - learning_rate: 5.0000e-04
# Epoch 11/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 540ms/step - loss: 0.0312 - mae: 0.1268 - mse: 0.0312 - val_loss: 0.0229 - val_mae: 0.1142 - val_mse: 0.0229 - learning_rate: 5.0000e-04
# Epoch 12/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 31s 576ms/step - loss: 0.0315 - mae: 0.1273 - mse: 0.0315 - val_loss: 0.0219 - val_mae: 0.1098 - val_mse: 0.0219 - learning_rate: 5.0000e-04
# Epoch 13/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 543ms/step - loss: 0.0302 - mae: 0.1264 - mse: 0.0302 - val_loss: 0.0213 - val_mae: 0.1075 - val_mse: 0.0213 - learning_rate: 5.0000e-04
# Epoch 14/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 553ms/step - loss: 0.0306 - mae: 0.1283 - mse: 0.0306 - val_loss: 0.0185 - val_mae: 0.0993 - val_mse: 0.0185 - learning_rate: 5.0000e-04
# Epoch 15/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 30s 559ms/step - loss: 0.0309 - mae: 0.1273 - mse: 0.0309 - val_loss: 0.0189 - val_mae: 0.1017 - val_mse: 0.0189 - learning_rate: 5.0000e-04
# Epoch 16/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 31s 578ms/step - loss: 0.0310 - mae: 0.1274 - mse: 0.0310 - val_loss: 0.0194 - val_mae: 0.1031 - val_mse: 0.0194 - learning_rate: 5.0000e-04
# Epoch 17/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 31s 580ms/step - loss: 0.0305 - mae: 0.1277 - mse: 0.0305 - val_loss: 0.0212 - val_mae: 0.1101 - val_mse: 0.0212 - learning_rate: 5.0000e-04
# Epoch 18/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 30s 570ms/step - loss: 0.0324 - mae: 0.1292 - mse: 0.0324 - val_loss: 0.0200 - val_mae: 0.1067 - val_mse: 0.0200 - learning_rate: 5.0000e-04
# Epoch 19/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 540ms/step - loss: 0.0309 - mae: 0.1280 - mse: 0.0309 - val_loss: 0.0193 - val_mae: 0.1037 - val_mse: 0.0193 - learning_rate: 5.0000e-04
# Epoch 20/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 538ms/step - loss: 0.0300 - mae: 0.1272 - mse: 0.0300 - val_loss: 0.0205 - val_mae: 0.1076 - val_mse: 0.0205 - learning_rate: 2.5000e-04
# Epoch 21/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 538ms/step - loss: 0.0300 - mae: 0.1272 - mse: 0.0300 - val_loss: 0.0200 - val_mae: 0.1058 - val_mse: 0.0200 - learning_rate: 2.5000e-04
# Epoch 22/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 545ms/step - loss: 0.0313 - mae: 0.1282 - mse: 0.0313 - val_loss: 0.0193 - val_mae: 0.1036 - val_mse: 0.0193 - learning_rate: 2.5000e-04
# Epoch 23/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 30s 561ms/step - loss: 0.0305 - mae: 0.1276 - mse: 0.0305 - val_loss: 0.0190 - val_mae: 0.1028 - val_mse: 0.0190 - learning_rate: 2.5000e-04
# Epoch 24/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 515ms/step - loss: 0.0307 - mae: 0.1273 - mse: 0.0307 - val_loss: 0.0201 - val_mae: 0.1065 - val_mse: 0.0201 - learning_rate: 2.5000e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - loss: 0.0235 - mae: 0.1122 - mse: 0.0235
#
# Test Results:
# loss: 0.0237
# compile_metrics: 0.1126
# INFO:tensorflow:Assets written to: C:\Users\VIRAT\AppData\Local\Temp\tmp8p7lnsr7\assets
# INFO:tensorflow:Assets written to: C:\Users\VIRAT\AppData\Local\Temp\tmp8p7lnsr7\assets
# Saved artifact at 'C:\Users\VIRAT\AppData\Local\Temp\tmp8p7lnsr7'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 320, 320, 3), dtype=tf.float32, name='keras_tensor_270')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   2315004874592: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2315004874768: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2315004882160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005169856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005171440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315004886560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005167568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005178128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005175664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005179184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005174080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005173200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005169504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005200864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005200688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005202800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005201744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005173552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005207376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005210896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005205792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005204912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005198752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012653120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012653472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005214064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012654000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005205264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012660688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012663152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012658048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012661040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012784896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012784368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012666496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012785776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012793872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012791408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012794928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012789824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012788944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012800032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012792288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012796160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012798976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012798800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315012789296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013150448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013152912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013147808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013146928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013150624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013150272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013156784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013159776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013244176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013251216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013248928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013244528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013247344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013250160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013257904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013257024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013256672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013362384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013366256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013363792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013367312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013361328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013360800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013372416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013369952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013373472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013368368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013365904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013359568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013460688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013463152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013458048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013457168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013469136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013468256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013471248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013470720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013468080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013510720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013513184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013507024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013506496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013510896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013510544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013517056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013520224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007149152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315013505088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007154784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007157248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007152144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007151264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007163232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007162352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007162000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007333248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007162176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007334832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007338352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007328496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007331488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315007336064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006805088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006804032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006805792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006805968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006814064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006811600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006815120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006810016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006809136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006813008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006726864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006728976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006722112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006820048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006730560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006734080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006726512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006727216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006725808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006731440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006731792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006737424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006592448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006725984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006598080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006600544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006595440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006594560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006606528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006605648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006605296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006514400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006518448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006515984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006519504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006512112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006512640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006515280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006412224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006411168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006412928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006413104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006511408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006418736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006422256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006417152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006416272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006420144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006350384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006352496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006348096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006356544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006354080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006357600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006350032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006350736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006353376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006905680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006908144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006902688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006906560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006349504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006912192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006915712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006910608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006909728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006913600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006237104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006239744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006234816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006243792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006241328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006244848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006236576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006237984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006910080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006121184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006123648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006118544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006117664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006236048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006127696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006131216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006126112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006125232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006129104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006058816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006061456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006056528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006065504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006063040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006060224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006058288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006059696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006125584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005992048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005994512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005989408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005988528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005985184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005991872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005997152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005999440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315006000848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005999088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005864144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005866784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005861856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005866080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005854288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005863968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005869072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005740480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005996448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005744704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005747168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005742064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005740128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005753680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005751216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005754736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005749632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005748752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005752624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005354656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005357296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005352368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005361344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005358880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005356064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005354128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005355536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005436752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005435344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005437808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005432704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005431824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005435696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005435168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005440448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005442736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005510400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005520432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005510928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005523072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005518144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005522368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005609056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005608528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005525184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005608176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005618912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005617504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005619968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005614864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005613984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005617856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009606576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009606048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315005621552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009607456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009618368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009615024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009621008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009616080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009620304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009722144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009721968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009723904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009723024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009733232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009730768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009734288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009729184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009728304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009732176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009805120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009806880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009803008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009806000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009816912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009813568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009814624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009814976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009812512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009887920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009890384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009884928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009885456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009899008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009896544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009900064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009894960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009894080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315009885808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010036432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010038896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010033792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010032912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010044880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010044000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010046992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010046464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010043824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010102848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010105312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010099152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010098624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010103024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010102672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010109184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010112352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010180192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010097920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010185824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010188288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010183184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010182304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010194272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010193392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010193040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010315136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010319184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010316720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010320240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010312848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010313376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010317952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010442336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010441280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010443040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010443216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010451312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010448848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010452368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010447264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010446384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010450256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010527952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010530064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010523200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010534112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010531648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010535168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010527600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010528304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010532880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010608112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010610048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010605120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010608992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010619728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010620432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315010527072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2315011047664: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model size: 11.55 MB
